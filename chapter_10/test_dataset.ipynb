# %% [markdown]
# <h1><font color="red">Test dataset</font></h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split # for splitting data into train and test
from sklearn.tree import DecisionTreeClassifier # Decision Tree model classifier
from sklearn.ensemble import RandomForestClassifier # RandomForest model classification
from sklearn.metrics import classification_report,confusion_matrix # classification report purposes


import warnings
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv("C:/Users/91852/Downloads/sklearn test/sklearn test/IDS_test.csv")

# %%
df1
# Out:
#           ID  Destination Port  Flow Duration  Total Fwd Packets  \
# 0          0                80       99575743                  7
# 1          1                80      107429687                  2
# 2          2                80          17291                  2
# 3          3                80       85038140                  5
# 4          4                80       82963302                  8
# ...      ...               ...            ...                ...
# 43289  43289                80       82746195                  6
# 43290  43290                53         183040                  4
# 43291  43291               443      117811197                 12
# 43292  43292                80        5023362                  3
# 43293  43293                53            272                  2
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                           5                          401
# 1                           1                          662
# ...

# %%
df1.shape
# Out:
# (43294, 79)

# %% [markdown]
# # Data Pre-processing

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43294 entries, 0 to 43293
# Data columns (total 79 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           43294 non-null  int64
#  1   Destination Port             43294 non-null  int64
#  2   Flow Duration                43294 non-null  int64
#  3   Total Fwd Packets            43294 non-null  int64
#  4   Total Backward Packets       43294 non-null  int64
#  5   Total Length of Fwd Packets  43294 non-null  int64
#  6   Total Length of Bwd Packets  43294 non-null  int64
#  7   Fwd Packet Length Max        43294 non-null  int64
#  8   Fwd Packet Length Min        43294 non-null  int64
#  9   Fwd Packet Length Mean       43294 non-null  float64
#  10  Fwd Packet Length Std        43294 non-null  float64
#  11  Bwd Packet Length Max        43294 non-null  int64
#  12  Bwd Packet Length Min        43294 non-null  int64
# ...

# %%
print(df1.head())
# Out:
#    ID  Destination Port  Flow Duration  Total Fwd Packets  \
# 0   0                80       99575743                  7
# 1   1                80      107429687                  2
# 2   2                80          17291                  2
# 3   3                80       85038140                  5
# 4   4                80       82963302                  8
#
#    Total Backward Packets  Total Length of Fwd Packets  \
# 0                       5                          401
# 1                       1                          662
# 2                       0                           12
# 3                       7                          338
# 4                       6                          375
#
#    Total Length of Bwd Packets  Fwd Packet Length Max  Fwd Packet Length Min  \
# 0                        11595                    377                      0
# 1                            6                    662                      0
# ...

# %%
df1.head()
# Out:
#    ID  Destination Port  Flow Duration  Total Fwd Packets  \
# 0   0                80       99575743                  7
# 1   1                80      107429687                  2
# 2   2                80          17291                  2
# 3   3                80       85038140                  5
# 4   4                80       82963302                  8
#
#    Total Backward Packets  Total Length of Fwd Packets  \
# 0                       5                          401
# 1                       1                          662
# 2                       0                           12
# 3                       7                          338
# 4                       6                          375
#
#    Total Length of Bwd Packets  Fwd Packet Length Max  Fwd Packet Length Min  \
# 0                        11595                    377                      0
# 1                            6                    662                      0
# ...

# %%
df1.describe()
# Out:
#                  ID  Destination Port  Flow Duration  Total Fwd Packets  \
# count  43294.000000      43294.000000   4.329400e+04       43294.000000
# mean   21646.500000       5706.111886   2.765915e+07          14.791195
# std    12498.045614      15735.386218   4.255524e+07        1226.536554
# min        0.000000          0.000000  -1.000000e+00           1.000000
# 25%    10823.250000         53.000000   1.970000e+02           2.000000
# 50%    21646.500000         80.000000   6.117150e+04           2.000000
# 75%    32469.750000        443.000000   8.224463e+07           7.000000
# max    43293.000000      63913.000000   1.200000e+08      198590.000000
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            43294.000000                 4.329400e+04
# mean                17.241650                 5.718862e+02
# std               1629.427964                 8.065294e+03
# min                  0.000000                 0.000000e+00
# ...

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of           ID  Destination Port  Flow Duration  Total Fwd Packets  \
# 0          0                80       99575743                  7
# 1          1                80      107429687                  2
# 2          2                80          17291                  2
# 3          3                80       85038140                  5
# 4          4                80       82963302                  8
# ...      ...               ...            ...                ...
# 43289  43289                80       82746195                  6
# 43290  43290                53         183040                  4
# 43291  43291               443      117811197                 12
# 43292  43292                80        5023362                  3
# 43293  43293                53            272                  2
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                           5                          401
# ...

# %%
df1.isnull()
# Out:
#           ID  Destination Port  Flow Duration  Total Fwd Packets  \
# 0      False             False          False              False
# 1      False             False          False              False
# 2      False             False          False              False
# 3      False             False          False              False
# 4      False             False          False              False
# ...      ...               ...            ...                ...
# 43289  False             False          False              False
# 43290  False             False          False              False
# 43291  False             False          False              False
# 43292  False             False          False              False
# 43293  False             False          False              False
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                       False                        False
# 1                       False                        False
# ...

# %%
# Check for null values
print(df1.isnull().sum())
# Out:
# ID                        0
# Destination Port          0
# Flow Duration             0
# Total Fwd Packets         0
# Total Backward Packets    0
#                          ..
# Active Min                0
# Idle Mean                 0
# Idle Std                  0
# Idle Max                  0
# Idle Min                  0
# Length: 79, dtype: int64

# %%
columns = df1.columns
count = 0
for i in df1.isnull().sum():
    print("{} : {}".format(columns[count],i))
    count+=1
# Out:
# ID : 0
# Destination Port : 0
# Flow Duration : 0
# Total Fwd Packets : 0
# Total Backward Packets : 0
# Total Length of Fwd Packets : 0
# Total Length of Bwd Packets : 0
# Fwd Packet Length Max : 0
# Fwd Packet Length Min : 0
# Fwd Packet Length Mean : 0
# Fwd Packet Length Std : 0
# Bwd Packet Length Max : 0
# Bwd Packet Length Min : 0
# Bwd Packet Length Mean : 0
# Bwd Packet Length Std : 0
# Flow Bytes/s : 56
# Flow Packets/s : 0
# Flow IAT Mean : 0
# Flow IAT Std : 0
# Flow IAT Max : 0
# Flow IAT Min : 0
# Fwd IAT Total : 0
# Fwd IAT Mean : 0
# Fwd IAT Std : 0
# Fwd IAT Max : 0
# Fwd IAT Min : 0
# Bwd IAT Total : 0
# Bwd IAT Mean : 0
# Bwd IAT Std : 0
# Bwd IAT Max : 0
# Bwd IAT Min : 0
# Fwd PSH Flags : 0
# Bwd PSH Flags : 0
# Fwd URG Flags : 0
# Bwd URG Flags : 0
# Fwd Header Length : 0
# Bwd Header Length : 0
# Fwd Packets/s : 0
# Bwd Packets/s : 0
# Min Packet Length : 0
# Max Packet Length : 0
# Packet Length Mean : 0
# Packet Length Std : 0
# Packet Length Variance : 0
# ...

# %% [markdown]
#   There are missing values in Flow Bytes/s, we have to drop them

# %%
df1 = df1.dropna()

# %%
numerical_cols = [one for each,one in zip(list(df1.dtypes),df1.dtypes.index)  if each == 'float64']
df1 = df1.drop(numerical_cols,axis = 1)

# %%
df1.shape   # original value(43294) -  nullvalue(56)
# Out:
# (43238, 55)

# %%
df=pd.read_csv("C:/Users/91852/Documents/sklearn test/IDS_train.csv")
df
# Out:
#             ID  Destination Port  Flow Duration  Total Fwd Packets  \
# 0            0                22        1420155                 37
# 1            1                80       63122325                  7
# 2            2                80       85039076                  6
# 3            3               443        5379977                  5
# 4            4                80       84220258                  8
# ...        ...               ...            ...                ...
# 129874  129874                80      101268629                 10
# 129875  129875                53      118727713                  4
# 129876  129876               443       31246630                  3
# 129877  129877                80        5183052                  3
# 129878  129878                80        5280210                  4
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# 0                           46                         2634
# ...

# %%
df.Label.unique()
# Out:
# array(['BENIGN', 'DoS Slowhttptest', 'DoS Hulk', 'DoS GoldenEye',
#        'DoS slowloris'], dtype=object)

# %%
df1.shape
# Out:
# (43238, 55)

# %% [markdown]
# ### Labeling the predictions

# %%
predictions = dtree.predict(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14320\2069956421.py in <module>
# ----> 1 predictions = dtree.predict(df1)
#
# NameError: name 'dtree' is not defined

# %% [markdown]
# Exploring the impact of social media on consumer behavior can be a complex and multi-faceted topic. However, some potential areas to explore might include:
#
# 1.Social media advertising: Many businesses use social media platforms to advertise their products and services to potential customers. Researching the effectiveness of social media advertising in terms of driving consumer behavior could be a valuable area of study.
#
# 2.Social media influencers: In recent years, social media influencers have become an increasingly popular way for brands to reach consumers. Investigating the impact of influencer marketing on consumer behavior could be a fruitful area of research.
#
# 3.User-generated content: Social media platforms also provide a space for users to share their own content related to brands and products. Studying the impact of user-generated content on consumer behavior could be an interesting area to explore.
#
# 4.Social media and customer service: Many businesses use social media platforms as a way to provide customer service to their customers. Investigating the impact of social media customer service on consumer behavior could be a valuable area of research.
#
# 5.Social media and brand reputation: Social media can have a significant impact on a brand's reputation, particularly when negative feedback or reviews are shared. Researching the impact of social media on brand reputation and how it influences consumer behavior could be an important area to explore.
#
# Overall, there are many different ways in which social media can impact consumer behavior. Exploring these areas through research and analysis can provide valuable insights for businesses looking to use social media to reach and engage with their target audience.

# %% [markdown]
# The COVID-19 pandemic has had a significant impact on the Indian economy. The government imposed a nationwide lockdown in March 2020 to contain the spread of the virus, which resulted in a sharp decline in economic activity. The following are some of the impacts of COVID-19 on the Indian economy:
#
# 1.GDP contraction: India's GDP contracted by a record 7.7% in the financial year 2020-21, the worst performance in four decades. This was primarily due to the disruption caused by the pandemic.
#
# 2.Job losses: The pandemic has led to job losses in several sectors, particularly in the informal sector. According to a report by the Centre for Monitoring Indian Economy, the unemployment rate in April 2020 was 23.5%.
#
# 3.Disruption of supply chains: The lockdown disrupted supply chains, affecting manufacturing and export-oriented industries. This resulted in a decline in exports and a trade deficit.
#
# 4.Decrease in consumption: The pandemic has also led to a decrease in consumption, as people are hesitant to spend due to uncertainty about the future. This has affected several sectors, including retail, hospitality, and travel.
#
# 5.Government spending: The government has announced several stimulus packages to support the economy, including measures to increase liquidity, provide financial support to small businesses, and increase public investment in infrastructure.
#
# In conclusion, the COVID-19 pandemic has had a significant impact on the Indian economy, with a sharp contraction in GDP, job losses, disruption of supply chains, and decreased consumption. However, the government's measures to support the economy may help mitigate the impact of the pandemic in the long run.
