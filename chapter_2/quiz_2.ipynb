# %%
# 1) what is correct syntax to output hello in python
> a.p("hello")
> b.print("hello")
> c.echo("hello")
> d.p "helloworld"

# %%
# 2) how to insert comments in python
> a.#hai
> b./*hai*/
> c.//hai
> d./hai/

# %%
# 3) how to creat variable with numeric value 5
> a.x=5
> b.x=int(5)
> c.x="5"
> d.both 1 and 2

# 4) what is extension of python file
> a).py
> b) .p
> c) .txt
> d) .pt 

# 5) what is the syntax to output type of variable or objrct in python
> a) print(typeof(x))
> b) print(type(x))
> c) print(typeOf(x))
> d) print(type-x))

# 6) what is the correct syntax to return 1'st value in string
> a) a="welcome"{0]}
> b) a=sub("welcome",0,1
> c) a="welcome".[0]
> d) a="welcome"[0]

# 7) which operator is used to compare two values
> a) "+="
> b) "<>"
> c) "><"
> d) "=="

# 8) What is the output of print(2 ** 3 ** 2)
> a) 64
> b) 512
> c) 121
> d) 36

# 9) which collection does not allow duplicates
> a) set 
> b) tuple 
> c) dictionary 
> d) both a and c

# 10) "What is the output of the following union operation

# set1 = {10, 20, 30, 40}
# set2 = {50, 20, ""10"", 60}

# set3 = set1.union(set2)
# print(set3)"
> a)  {40, 10, 50, 20, 60, 30}
> b)  {40, ’10’, 50, 20, 60, 30}
> c) {40, 10, ’10’, 50, 20, 60, 30}
> d) syntax error

# 11) In Python 3, what is the type of type(range(5))
> a) int
> b) list
> c) range
> d) tuple

# 12) In Python 3, the maximum value for an integer is
> a) 263 - 1:
> b) 264 - 1:
> c) NO LIMIT
> d) 123-1

# 13) Which of these is not a core data type?
> a) LIST
> b) CLASS
> c) TUPLE
> d) SET

# 14) Which of the following function convert a string to a float in python?
> a) int(x [,base])
> b) float(x)
> c) str(x)
> d) list(str(x))

# 15) Choose the correct way to access 'c' from the following list list=[1,2,3,[2,3,4,['a','c',['b','c']]]]
> a)list[3][2][2][0]
> b) list[2][3][2][0]
> c)list[3][3][2][1]
> d) list[3][3][1][1]

# 16) what is the result of this expression 'current'.index('r')
> a) 3
> b) 2
> c) 5
> d) 1

# 17) Dictionary keys are
> a) string datatype
> b) int datatype
> c) float datatype
> d) non of these

# 18) Select all correct ways to copy a dictionary in Python
> a) dict2 = dict(dict1)
> b) dict2 = dict(dict1.items())
> c) dict2 = dict1
> d) dict2 = cop(dict1)

# 19) Select which is true for Python tuple
> a) A tuple maintains the order of items
> b) A tuple is unordered
> c) We can change the tuple once create
> d) Tuples are mutable

# 20) Choose the correct function from the following list to get the random integer between 99 to 200, which is divisible by 3.
> a) random.randrange(99, 200, 3)
> b) random.randint(99, 200, 3)
> c) random.random(99, 200, 3)
> d) random.choice(99, 200, 3)

# 21) What is the method for accepting inputs dynamically in Python?
> a) inputs()
> b) input()
> c) rawinput()
> d) rawinputs()

# Choose complex number from the following.
Syntax to print a string 3 times in Python 3.8
Lists are .....................
What is the method for deleting last element in a List?
Positive Indicies of a Tuple always starts with.......
How to display all keys of a dictionary?
Choose set intersection operator from the following.
How to open a text file in write mode?
What is the correct way of closing a file?
how to creat variable with numeric value 5
what is extension of python file
what is the syntax to output type of variable or objrct in python
what is the correct syntax to return 1'st value in string
which operator is used to compare two values
What is the output of print(2 ** 3 ** 2)
which collection does not allow duplicates
"What is the output of the following union operation

set1 = {10, 20, 30, 40}
set2 = {50, 20, ""10"", 60}

set3 = set1.union(set2)
print(set3)"
In Python 3, what is the type of type(range(5))
In Python 3, the maximum value for an integer is
Which of these is not a core data type?
Which of the following function convert a string to a float in python?
Choose the correct way to access 'c' from the following list list=[1,2,3,[2,3,4,['a','c',['b','c']]]]
what is the result of this expression 'current'.index('r')
Dictionary keys are
Select all correct ways to copy a dictionary in Python
Select which is true for Python tuple
Choose the correct function from the following list to get the random integer between 99 to 200, which is divisible by 3.
What is the method for accepting inputs dynamically in Python?
Choose complex number from the following.
Syntax to print a string 3 times in Python 3.8
Lists are .....................
What is the method for deleting last element in a List?
Positive Indicies of a Tuple always starts with.......
How to display all keys of a dictionary?
Choose set intersection operator from the following.
How to open a text file in write mode?
What is the correct way of closing a file?
